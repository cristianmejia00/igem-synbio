# %% [markdown]
# # Topic Naming with OpenAI — iGEM Teams (Part 1)
#
# Loads the **iGEM Teams** topic info and corpus produced in
# `02-topic_model/`, then sends representative documents per cluster to GPT to
# obtain:
#
# 1. A **description** of each topic cluster.
# 2. An **enhanced (synthesised) description**.
# 3. A short **cluster name**.
#
# Prompts are loaded from `prompts.yaml`. Results are saved as
# `teams_topic_names.txt` alongside the topic models in
# `assets/topic_models/`.

# %%
# ── Make the shared aux/ package importable ───────────────────────────────────
# These notebooks live one level below 03-topic_names/, where the aux/ package
# resides; add that folder to the import path.
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

# %%
from aux.paths import MODELS_DIR, OPENAI_MODEL, TOP_N_DOCS
from aux.openai_client import load_prompts, make_client
from aux.tables import load_topic_corpus, save_topic_names
from aux.naming import name_topics

# ── CONFIG: iGEM Teams ──────────────────────────────────────────────────
PREFIX = "teams"
ID_COL = "UT"
MODEL  = OPENAI_MODEL          # OpenAI model used for naming

prompts = load_prompts()
client = make_client()
print(f"Theme: {prompts['theme']}")
# Out:
# Theme: Synthetic Biology

# %% [markdown]
# ## 1. Load topic info and corpus

# %%
topic_info, df = load_topic_corpus(PREFIX, ID_COL)
n_topics = topic_info.Topic.max() + 1
print(f"Teams: {len(df):,} docs, {n_topics} topics")
# Out:
# Teams: 3,811 docs, 154 topics

# %% [markdown]
# ## 2. Generate descriptions and names

# %%
print("Naming iGEM Teams topics...")
names = name_topics(df, topic_info, client, prompts, model=MODEL, top_n=TOP_N_DOCS)
names
# Out:
# Naming iGEM Teams topics...
#   Topic 0 ... Synthetic Biology for Controlled Gene Expression and Pattern Formation
#   Topic 1 ... Pest and Vector Control
#   Topic 2 ... Synthetic Biology for Plant Disease Detection and Control
#   Topic 3 ... Biofilm and Quorum Sensing Control
#   Topic 4 ... Synthetic Biology Design and Automation Tools
#   Topic 5 ... Genetic Device Stability and Evolution
#   Topic 6 ... Synthetic Biology for Environmental Pollution Remediation
#   Topic 7 ... Synthetic Biology for MicroRNA Detection
#   Topic 8 ... Synthetic Gene Circuit Engineering
#   Topic 9 ... Synthetic Biology Tools for Genetic Control and Engineering
#   Topic 10 ... Synthetic Biology Tools for Genetic and Molecular Engineering
#   Topic 11 ... Phage-based Synthetic Biology
#   Topic 12 ... Synthetic Biology for Water Pollution Detection and Remediation
#   Topic 13 ... Synthetic Biology for Sustainable Materials
#   Topic 14 ... Synthetic Biology in Cancer Therapeutics
#   Topic 15 ... Synthetic Biology-Driven Biosensor Technologies
#   Topic 16 ... Synthetic Biology-Driven Biosensing
#   Topic 17 ... Environmental Bioremediation and Monitoring
#   Topic 18 ... Synthetic Biology for Accessible and Industrial Biomanufacturing
#   Topic 19 ... Synthetic Biology Diagnostic Platforms
#   Topic 20 ... Cyanobacteria-Driven Synthetic Biological Systems
#   Topic 21 ... Synthetic Biology for Biological Computing
#   Topic 22 ... Synthetic Biology for Environmental Bioremediation
#   Topic 23 ... Synthetic Biology-Driven Biological Delivery and Therapeutic Systems
#   Topic 24 ... Synthetic Biological System Engineering
#   Topic 25 ... Synthetic Biology Diagnostic and Biosensing
#   Topic 26 ... Environmental Bioremediation and Resource Recovery
#   Topic 132 ... Synthetic Biology for Sustainable Agriculture and Environmental Solutions
#   Topic 133 ... DNA Nanostructure Engineering
#   Topic 134 ... Synthetic Biology for Coral Reef Conservation
#   Topic 135 ... Synthetic Microbial Communities and Metabolic Engineering
#   Topic 136 ... Synthetic Biology for Biofuel and Bioproducts
#   Topic 137 ... Synthetic Biology for Food Safety and Toxin Detection
#   Topic 138 ... Synthetic Biology for Material and Tissue Engineering
#   Topic 139 ... Synthetic Biology for Cadmium Detection and Remediation
#   Topic 140 ... Synthetic Biology for Sustainable Bioproduction
#   Topic 141 ... Synthetic Biology for Personalized Cancer Diagnostics and Therapeutics
#   Topic 142 ... Synthetic Biology for Sustainable Agriculture and Soil Management
#   Topic 143 ... Synthetic Biology for Lead Detection and Remediation
#   Topic 144 ... Synthetic Biology for Targeted Cancer Therapy
#   Topic 145 ... Environmental and Agricultural Biosensing
#   Topic 146 ... Synthetic Biology for Food Security and Safety
#   Topic 147 ... Synthetic Biology for Environmental and Industrial Surface Protection
#   Topic 148 ... Heavy Metal Biosensors
#   Topic 149 ... Engineered Microbial Therapeutics
#   Topic 150 ... Synthetic Biology for Bacterial Detection and Control
#   Topic 151 ... Synthetic Biology for Mental Health and Gut Microbiome
#   Topic 152 ... Synthetic Biology for Environmental Bioremediation
#   Topic 153 ... Synthetic Biology for Mental and Gut Health Modulation
#      topic                                               name  \
# 0        0  Synthetic Biology for Controlled Gene Expressi...
# 1        1                            Pest and Vector Control
# 2        2  Synthetic Biology for Plant Disease Detection ...
# 3        3                 Biofilm and Quorum Sensing Control
# 4        4      Synthetic Biology Design and Automation Tools
# ..     ...                                                ...
# 149    149                  Engineered Microbial Therapeutics
# 150    150  Synthetic Biology for Bacterial Detection and ...
# 151    151  Synthetic Biology for Mental Health and Gut Mi...
# 152    152  Synthetic Biology for Environmental Bioremedia...
# 153    153  Synthetic Biology for Mental and Gut Health Mo...
#
#                                            description  \
# 0    This cluster focuses on harnessing synthetic b...
# 1    This cluster focuses on harnessing advanced ge...
# 2    This cluster focuses on leveraging synthetic b...
# 3    This cluster focuses on leveraging synthetic b...
# 4    This cluster centers on the advancement of too...
# ..                                                 ...
# 149  This cluster centers on harnessing Synthetic B...
# 150  This cluster focuses on leveraging synthetic b...
# 151  This cluster focuses on harnessing synthetic b...
# 152  This cluster centers on leveraging synthetic b...
# 153  This cluster focuses on harnessing synthetic b...
#
#                                        raw_description
# 0    The common topic of this cluster is the applic...
# 1    The common topic of these texts is the develop...
# 2    The common topic across these texts is the app...
# 3    The main topic of this cluster is the applicat...
# 4    The main topic of this cluster is **Synthetic ...
# ..                                                 ...
# 149  The common topic of this cluster is the applic...
# 150  The common topic across these texts is the app...
# 151  The common topic of this cluster is the develo...
# 152  The common topic of these texts is the applica...
# 153  The common topic of this cluster is the applic...
#
# [154 rows x 4 columns]

# %% [markdown]
# ## 3. Save results

# %%
save_topic_names(names, PREFIX)
print(f"Saved {len(names)} topic names → {MODELS_DIR / f'{PREFIX}_topic_names.txt'}")
# Out:
# Saved 154 topic names → /Users/cristian/Desktop/GitHub/igem-synbio/assets/topic_models/teams_topic_names.txt
